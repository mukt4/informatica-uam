# %% [markdown]
# <h1>Práctica 2: Vecinos Próximos y Regresión Logística</h1>
#
# Practica realizada por Tomas Higuera Viso y Alejandro Naranjo Jimenez
#
# Importamos todas las librerias que usaremos en el notebook

# %%
from Datos import Datos
from plotModel import plotModel
from IPython.display import *
from plot_notebook import *

import p2_scikit
import EstrategiaParticionado 
import Clasificador
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h2>Clasificador Vecinos Proximos</h2>
#
# En este apartado utilizaremos el algoritmo de clasificacion vecinos proximos, usaremos distintos valores de k para comaprar las probabilidades.
# Los valores de k que usaremos son 1,3,5,11,21,51. La razon de usar valores impares es evitar problemas con los empates.
# En las pruebas de este algoritmo usaremos validacion cruzada.
#
# Declaramos la estrategia de particionado.

# %%
estrategia=EstrategiaParticionado.ValidacionCruzada(5)

# %% [markdown]
# Declaracion de la lista que contiene los valores K con los que se ejecutara el algoritmo.

# %%
lista_k = [1, 3, 5, 11, 21, 51]

# %% [markdown]
# <h3>example1.data</h3>
#
# Ejecutaremos el algoritmo de vecinos proximos con el conjunto de datos example1. Ejecutaremos el algoritmo tanto normalizado como  sin normalizar para comparar los resultados.

# %%
dataset=Datos('data/example1.data')

# %%
tabla1 = exe_KNN(dataset,estrategia, lista_k, True)

print("**Tasa de error [media ± desv.tip]**")
display(HTML(tabla1))
# Out:
# **Tasa de error [media ± desv.tip]**
# <table><tr> <th>k</th> <th>Sin Normalizar</th><th>Normalizando</th></tr><tr> <td>1</td><td>0.1575  ±   0</td><td>0.0225  ±   0</td> </tr><tr> <td>3</td><td>0.0608  ±   0</td><td>0.0100  ±   0</td> </tr><tr> <td>5</td><td>0.0385  ±   0</td><td>0.0121  ±   0</td> </tr><tr> <td>11</td><td>0.1007  ±   0</td><td>0.0681  ±   0</td> </tr><tr> <td>21</td><td>0.0994  ±   0</td><td>0.0940  ±   0</td> </tr><tr> <td>51</td><td>0.1025  ±   0</td><td>0.1187  ±   0</td> </tr></table>

# %%
exe_KNN_plot(dataset,estrategia,21,"example1.data",False)

# %%
exe_KNN_plot(dataset,estrategia,21,"example1.data",True)

# %% [markdown]
# Como podemos observar ambas soluciones, tanto normalizadas como sin normalizar obtienen resultados muy parejos. Las tasas de error a pesar de ser parecidas en general son menores las del caso normalizado.
#
#
# <h3>example2.data</h3>
#
# Debido al tipo de datos, no se hara la normalizacion con este conjunto, ya que tratamos con datos discretos y no tiene sentido hacerlo.

# %%
dataset=Datos('data/example2.data')

# %%
table2 = exe_KNN(dataset,estrategia, lista_k, False)

print("**Tasa de error [media ± desv.tip]**")
display(HTML(table2))
# Out:
# **Tasa de error [media ± desv.tip]**
# <table><tr> <th>k</th> <th>Sin Normalizar</th></tr><tr> <td>1</td><td>0.0000  ±   0</td></tr><tr> <td>3</td><td>0.0000  ±   0</td></tr><tr> <td>5</td><td>0.0000  ±   0</td></tr><tr> <td>11</td><td>0.0000  ±   0</td></tr><tr> <td>21</td><td>0.0000  ±   0</td></tr><tr> <td>51</td><td>0.0000  ±   0</td></tr></table>

# %%
exe_KNN_plot(dataset,estrategia,3,"example2.data",False)

# %% [markdown]
# Como hemos mencionado anteriormente, al tratarse de atributos discretos no normalizaremos. La tasa de error obtenida es de 0%, esto se debe a la gran separacion de ambas clases.
#
# <h3>example3.data</h3>

# %%
dataset=Datos('data/example3.data')

# %%
table3 = exe_KNN(dataset,estrategia, lista_k, True)

print("**Tasa de error [media ± desv.tip]**")
display(HTML(table3))
# Out:
# **Tasa de error [media ± desv.tip]**
# <table><tr> <th>k</th> <th>Sin Normalizar</th><th>Normalizando</th></tr><tr> <td>1</td><td>0.0000  ±   0</td><td>0.0000  ±   0</td> </tr><tr> <td>3</td><td>0.0000  ±   0</td><td>0.0000  ±   0</td> </tr><tr> <td>5</td><td>0.0000  ±   0</td><td>0.0000  ±   0</td> </tr><tr> <td>11</td><td>0.0000  ±   0</td><td>0.0000  ±   0</td> </tr><tr> <td>21</td><td>0.0000  ±   0</td><td>0.0000  ±   0</td> </tr><tr> <td>51</td><td>0.0111  ±   0</td><td>0.0085  ±   0</td> </tr></table>

# %%
exe_KNN_plot(dataset,estrategia,7,"example3.data",False)

# %%
exe_KNN_plot(dataset,estrategia,7,"example3.data",True)

# %% [markdown]
# Como podemos observar ambas soluciones, tanto normalizadas como sin normalizar obtienen resultados muy parecidos, practicamente el 0% en ambos casos. Se obtienen unas fronteras muy bien marcadas.
#
# <h3>example4.data</h3>

# %%
dataset=Datos('data/example4.data')

# %%
table4 = exe_KNN(dataset,estrategia, lista_k, True)

print("**Tasa de error [media ± desv.tip]**")
display(HTML(table4))
# Out:
# **Tasa de error [media ± desv.tip]**
# <table><tr> <th>k</th> <th>Sin Normalizar</th><th>Normalizando</th></tr><tr> <td>1</td><td>0.0400  ±   0</td><td>0.0000  ±   0</td> </tr><tr> <td>3</td><td>0.0067  ±   0</td><td>0.0000  ±   0</td> </tr><tr> <td>5</td><td>0.0060  ±   0</td><td>0.0000  ±   0</td> </tr><tr> <td>11</td><td>0.0200  ±   0</td><td>0.0000  ±   0</td> </tr><tr> <td>21</td><td>0.0267  ±   0</td><td>0.0000  ±   0</td> </tr><tr> <td>51</td><td>0.0673  ±   0</td><td>0.0000  ±   0</td> </tr></table>

# %%
exe_KNN_plot(dataset,estrategia,7,"example4.data",False)

# %%
exe_KNN_plot(dataset,estrategia,7,"example4.data",True)

# %% [markdown]
# Sin normalizar obtenemos un error medio de aproximadamente el 5%, ademas, en la grafica sin normalizar se puede percibir ruido. Esto se debe a que es necesario normalizar al haber atributos continuos en este conjunto de datos.
#
# Al igual que en los casos anteriores en la grafica normalizada se pueden ver unas fronteras bien marcadas.
#
# <h3>wdbc.data</h3>

# %%
dataset=Datos('data/wdbc.data')

# %%
table_wdbc = exe_KNN(dataset,estrategia, lista_k, True)

print("**Tasa de error [media ± desv.tip]**")
display(HTML(table_wdbc))
# Out:
# **Tasa de error [media ± desv.tip]**
# <table><tr> <th>k</th> <th>Sin Normalizar</th><th>Normalizando</th></tr><tr> <td>1</td><td>0.0192  ±   0</td><td>0.0031  ±   0</td> </tr><tr> <td>3</td><td>0.0150  ±   0</td><td>0.0043  ±   0</td> </tr><tr> <td>5</td><td>0.0101  ±   0</td><td>0.0025  ±   0</td> </tr><tr> <td>11</td><td>0.0295  ±   0</td><td>0.0102  ±   0</td> </tr><tr> <td>21</td><td>0.0329  ±   0</td><td>0.0186  ±   0</td> </tr><tr> <td>51</td><td>0.0554  ±   0</td><td>0.0182  ±   0</td> </tr></table>

# %% [markdown]
# El error obtenido es de aproximadamente un 5% sin normalizar y un 1% normalizando.
#
# En este caso, al no tratarse de un conjunto de datos bidimensional, no podemos representarlo.
#
# <h2>Clasificador regresion logistica</h2>
#
# Los parametros de este clasificador seran, numero de epocas, constante de aprendizaje y si queremos que los datos con los que trabajamos esten normalizados.
#
# Declaramos las epocas con las que vamos a ejecutar el clasificador.

# %%
n_epocas = [1, 5, 10, 15, 20]

# %% [markdown]
# <h3>example1.data</h3>

# %%
dataset=Datos('data/example1.data')

# %%
table1 = exe_REG_LOG(dataset,estrategia,n_epocas, True)

print("**Tasa de error [media ± desv.tip]**")
display(HTML(table1))
# Out:
# **Tasa de error [media ± desv.tip]**
# <table><tr> <th>N epocas</th> <th>Sin Normalizar</th><th>Normalizando</th></tr><tr> <td>1</td><td>0.4875  ±   0</td><td>0.5350  ±   0</td> </tr><tr> <td>5</td><td>0.5275  ±   0</td><td>0.5862  ±   0</td> </tr><tr> <td>10</td><td>0.4845  ±   0</td><td>0.5079  ±   0</td> </tr><tr> <td>15</td><td>0.5011  ±   0</td><td>0.4081  ±   0</td> </tr><tr> <td>20</td><td>0.4992  ±   0</td><td>0.4108  ±   0</td> </tr></table>

# %%
exe_REG_LOG_plot(dataset,estrategia,21,"example1.data",False)

# %%
exe_REG_LOG_plot(dataset,estrategia,21,"example1.data",True)

# %% [markdown]
# Como se puede apreciar en las dos representaciones, ambas clasificaciones son malas, ya que los puntos no se situan en su color correctamente. El error obtenido es del 50% aproximadamente tanto con datos normalizados como sin normalizar.
#
# <h3>example2.data</h3>
#
# Al igual que haciamos en vecinos proximos este algoritmo se ejecutara sin normalizar, ya que se trata de atributos discretos.

# %%
dataset=Datos('data/example2.data')

# %%
table2 = exe_REG_LOG(dataset,estrategia,n_epocas, False)

print("**Tasa de error [media ± desv.tip]**")
display(HTML(table2))
# Out:
# **Tasa de error [media ± desv.tip]**
# <table><tr> <th>N epocas</th> <th>Sin Normalizar</th></tr><tr> <td>1</td><td>0.2983  ±   0</td></tr><tr> <td>5</td><td>0.2493  ±   0</td></tr><tr> <td>10</td><td>0.4500  ±   0</td></tr><tr> <td>15</td><td>0.4988  ±   0</td></tr><tr> <td>20</td><td>0.5000  ±   0</td></tr></table>

# %%
exe_REG_LOG_plot(dataset,estrategia,21,"example2.data",False)

# %% [markdown]
# Como nos ocurrio en el ejercicio anterior volvemos a obtener el mismo error de la separacion de clases. El error obtenido en los ejemplos es de apoximadamente 50%.
#
# <h3>example3.data</h3>

# %%
dataset=Datos('data/example3.data')

# %%
table3 = exe_REG_LOG(dataset,estrategia,n_epocas, True)

print("**Tasa de error [media ± desv.tip]**")
display(HTML(table3))
# Out:
# **Tasa de error [media ± desv.tip]**
# <table><tr> <th>N epocas</th> <th>Sin Normalizar</th><th>Normalizando</th></tr><tr> <td>1</td><td>0.4929  ±   0</td><td>0.5000  ±   0</td> </tr><tr> <td>5</td><td>0.5244  ±   0</td><td>0.5205  ±   0</td> </tr><tr> <td>10</td><td>0.5233  ±   0</td><td>0.5080  ±   0</td> </tr><tr> <td>15</td><td>0.4819  ±   0</td><td>0.4968  ±   0</td> </tr><tr> <td>20</td><td>0.5224  ±   0</td><td>0.4174  ±   0</td> </tr></table>

# %%
exe_REG_LOG_plot(dataset,estrategia,21,"example3.data",False)

# %%
exe_REG_LOG_plot(dataset,estrategia,21,"example3.data",True)

# %% [markdown]
# Nos vuelve a ocurrir lo mismo que en los conjuntos de datos anteriores, y obtenemos un error del 50%, tanto normalizando como sin normalizar.
#
# <h3>example4.data</h3>

# %%
dataset=Datos('data/example4.data')

# %%
table4 = exe_REG_LOG(dataset,estrategia, n_epocas, True)

print("**Tasa de error [media ± desv.tip]**")
display(HTML(table4))
# Out:
# **Tasa de error [media ± desv.tip]**
# <table><tr> <th>N epocas</th> <th>Sin Normalizar</th><th>Normalizando</th></tr><tr> <td>1</td><td>0.0100  ±   0</td><td>0.0000  ±   0</td> </tr><tr> <td>5</td><td>0.0000  ±   0</td><td>0.0000  ±   0</td> </tr><tr> <td>10</td><td>0.0000  ±   0</td><td>0.0000  ±   0</td> </tr><tr> <td>15</td><td>0.0000  ±   0</td><td>0.0000  ±   0</td> </tr><tr> <td>20</td><td>0.0000  ±   0</td><td>0.0000  ±   0</td> </tr></table>

# %%
exe_REG_LOG_plot(dataset,estrategia,21,"example4.data",False)

# %%
exe_REG_LOG_plot(dataset,estrategia,21,"example4.data",True)

# %% [markdown]
# En este caso podemos observar que la tasa de error es del 0%. Esto se debe a que los puntos se concentran en dos regiones permitiendonos separarlos de manera correcta.
#
# <h3>wdbc.data</h3>

# %%
dataset=Datos('data/wdbc.data')

# %%
table_wdbc = exe_REG_LOG(dataset,estrategia,n_epocas, True)

print("**Tasa de error [media ± desv.tip]**")
display(HTML(table_wdbc))
# Out:
# /home/tomas/Clasificador.py:270: RuntimeWarning: overflow encountered in exp
#   nxt = 1/(1 + np.exp(-wx))
# **Tasa de error [media ± desv.tip]**
# <table><tr> <th>N epocas</th> <th>Sin Normalizar</th><th>Normalizando</th></tr><tr> <td>1</td><td>0.1859  ±   0</td><td>0.0396  ±   0</td> </tr><tr> <td>5</td><td>0.1487  ±   0</td><td>0.0277  ±   0</td> </tr><tr> <td>10</td><td>0.1539  ±   0</td><td>0.0230  ±   0</td> </tr><tr> <td>15</td><td>0.1439  ±   0</td><td>0.0250  ±   0</td> </tr><tr> <td>20</td><td>0.0856  ±   0</td><td>0.0193  ±   0</td> </tr></table>

# %% [markdown]
# Al no tratarse de una tabla bidimensional, al igual que nos ocurria con vecinos proximos no podemos realizar una representacion grafica.
#
# El error obtenido es de un 15% sin normalizar y  un 5% normalizado, considerablemente mejor que en los tres primeros casos.
#
# <h2>Clasificador vecinos proximos con SCKLearn</h2>
#
# Probaremos el algoritmo con los mismos valores de k para poder comparar nuestros resultados con los obtenidos con ScikitLearn.

# %%
lista_k = [1, 3, 5, 11, 21, 51]

# %%
dataset=Datos('data/example1.data')
tableKnn1 = p2_scikit.Knn_Scikit(dataset, estrategia, lista_k)
display(HTML(tableKnn1))
# Out:
# /home/tomas/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /home/tomas/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)
# ...

# %% [markdown]
# <h3>example2.data</h3>

# %%
dataset=Datos('data/example2.data')
tableKnn2 = p2_scikit.Knn_Scikit(dataset, estrategia, lista_k)
display(HTML(tableKnn2))
# Out:
# /home/tomas/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /home/tomas/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)
# ...

# %% [markdown]
# <h3>example3.data</h3>

# %%
dataset=Datos('data/example3.data')
tableKnn3 = p2_scikit.Knn_Scikit(dataset, estrategia, lista_k)
display(HTML(tableKnn3))
# Out:
# /home/tomas/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /home/tomas/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)
# ...

# %% [markdown]
# <h3>example4.data</h3>

# %%
dataset=Datos('data/example4.data')
tableKnn4 = p2_scikit.Knn_Scikit(dataset, estrategia, lista_k)
display(HTML(tableKnn4))
# Out:
# /home/tomas/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /home/tomas/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)
# ...

# %% [markdown]
# Si comparamos nuestros resultados con los obtenidos con la libreria podemos observar como los resultados son muy parecidos.
#
# <h2>Clasificador regresion logistica con SCKLearn</h2>
#
# Al igual que en el clasificador anterior, el numero de epocas que usaremos sera el mismo que con nuestro clasificador para poder comparar despues resultados.

# %%
n_epocas = [1, 5, 10, 15, 20]

# %% [markdown]
# <h3>example1.data</h3>

# %%
dataset=Datos('data/example1.data')
tableRegLog1 = p2_scikit.RegLog_Scikit(dataset, estrategia, n_epocas)
display(HTML(tableRegLog1))
# Out:
# /home/tomas/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /home/tomas/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)
# ...

# %% [markdown]
# <h3>example2.data</h3>

# %%
dataset=Datos('data/example2.data')
tableRegLog2 = p2_scikit.RegLog_Scikit(dataset, estrategia, n_epocas)
display(HTML(tableRegLog2))
# Out:
# /home/tomas/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /home/tomas/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)
# ...

# %% [markdown]
# <h3>example3.data</h3>

# %%
dataset=Datos('data/example3.data')
tableRegLog3 = p2_scikit.RegLog_Scikit(dataset, estrategia, n_epocas)
display(HTML(tableRegLog3))
# Out:
# /home/tomas/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /home/tomas/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)
# ...

# %% [markdown]
# <h3>example4.data</h3>

# %%
dataset=Datos('data/example4.data')
tableRegLog4 = p2_scikit.RegLog_Scikit(dataset, estrategia, n_epocas)
display(HTML(tableRegLog4))
# Out:
# /home/tomas/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /home/tomas/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)
# ...

# %% [markdown]
# Al igual que nos ocurria con el algoritmo de vecinos proximos, nuestros resultados se asemejan en gran medida a los obtenidos haciendo uso de la libreria de ScikitLearn.
